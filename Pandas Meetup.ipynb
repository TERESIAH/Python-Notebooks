# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
pd.options.display.max_rows = 20
pd.options.display.float_format = '{:,.2f}'.format #supress scientific notation
plt.rcParams['figure.figsize'] = (16,8) #width 16 inches and height 8 inches

# %%
loan=pd.read_csv("D:/Cheat Sheets/Jupyter Notebooks/Exploratory-Data-Analysis-master/data/train.csv")
loan
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 604  LP002959  Female     Yes          1      Graduate            No
# 605  LP002960    Male     Yes          0  Not Graduate            No
# ...

# %%
loan["LoanAmount"]
# Out:
# 0        nan
# 1     128.00
# 2      66.00
# 3     120.00
# 4     141.00
#        ...
# 609    71.00
# 610    40.00
# 611   253.00
# 612   187.00
# 613   133.00
# Name: LoanAmount, Length: 614, dtype: float64

# %%
loan.index
# Out:
# RangeIndex(start=0, stop=614, step=1)

# %%
loan.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan.shape
# Out:
# (614, 13)

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               601 non-null object
# Married              611 non-null object
# Dependents           599 non-null object
# Education            614 non-null object
# Self_Employed        582 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB

# %%
loan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849               0.00         nan            360.00
# 1             4583           1,508.00      128.00            360.00
# 2             3000               0.00       66.00            360.00
# 3             2583           2,358.00      120.00            360.00
# 4             6000               0.00      141.00            360.00
#
#    Credit_History Property_Area Loan_Status
# 0            1.00         Urban           Y
# 1            1.00         Rural           N
# ...

# %%
loan.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849               0.00         nan            360.00
# 1             4583           1,508.00      128.00            360.00
# 2             3000               0.00       66.00            360.00
# 3             2583           2,358.00      120.00            360.00
# 4             6000               0.00      141.00            360.00
#
#    Credit_History Property_Area Loan_Status
# 0            1.00         Urban           Y
# 1            1.00         Rural           N
# ...

# %%
loan[['Education','LoanAmount']]
# Out:
#         Education  LoanAmount
# 0        Graduate         nan
# 1        Graduate      128.00
# 2        Graduate       66.00
# 3    Not Graduate      120.00
# 4        Graduate      141.00
# ..            ...         ...
# 609      Graduate       71.00
# 610      Graduate       40.00
# 611      Graduate      253.00
# 612      Graduate      187.00
# 613      Graduate      133.00
#
# [614 rows x 2 columns]

# %%
loan["LoanAmount"]>128
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 609    False
# 610    False
# 611     True
# 612     True
# 613     True
# Name: LoanAmount, Length: 614, dtype: bool

# %%
loan.groupby("Education").size()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# dtype: int64

# %%
loan[['ApplicantIncome']].describe()
# Out:
#        ApplicantIncome
# count           614.00
# mean          5,403.46
# std           6,109.04
# min             150.00
# 25%           2,877.50
# 50%           3,812.50
# 75%           5,795.00
# max          81,000.00

# %%
loan
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan[['Credit_History','Loan_Amount_Term','LoanAmount','CoapplicantIncome','ApplicantIncome']].describe()
# Out:
#        Credit_History  Loan_Amount_Term  LoanAmount  CoapplicantIncome  \
# count          564.00            600.00      592.00             614.00
# mean             0.84            342.00      146.41           1,621.25
# std              0.36             65.12       85.59           2,926.25
# min              0.00             12.00        9.00               0.00
# 25%              1.00            360.00      100.00               0.00
# 50%              1.00            360.00      128.00           1,188.50
# 75%              1.00            360.00      168.00           2,297.25
# max              1.00            480.00      700.00          41,667.00
#
#        ApplicantIncome
# count           614.00
# mean          5,403.46
# std           6,109.04
# min             150.00
# 25%           2,877.50
# 50%           3,812.50
# 75%           5,795.00
# max          81,000.00

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
ax1.set(title ="Histogram of ApplicantIncome")
ax2.set(title ="ViolinPlot of ApplicantIncome")
sns.distplot(a=loan[["ApplicantIncome"]], ax=ax1,bins=20)
sns.violinplot(y="ApplicantIncome",ax=ax2,bins=20,data=loan)

# %%
fig, ax = plt.subplots()
ax.set(title ="Histogram of ApplicantIncome")
sns.boxplot(y="ApplicantIncome", data=loan)

# %%
loan['Loan_Status'].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
loan['Loan_Status'].value_counts(normalize=True)
# Out:
# Y   0.69
# N   0.31
# Name: Loan_Status, dtype: float64

# %%
pd.crosstab(loan['Loan_Status'], loan['Education'], normalize=True)
# Out:
# Education    Graduate  Not Graduate
# Loan_Status
# N                0.23          0.08
# Y                0.55          0.13

# %%
loan.pivot_table(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount'],
               ['Loan_Amount_Term'], aggfunc='mean')
# Out:
#                   ApplicantIncome  CoapplicantIncome  LoanAmount
# Loan_Amount_Term
# 12.00                    4,625.00           2,857.00      111.00
# 36.00                    3,419.50               0.00      117.50
# 60.00                    5,032.50           2,850.50      140.00
# 84.00                    4,128.50           1,093.50      132.25
# 120.00                   2,792.67             362.00       22.33
# 180.00                   6,927.89           2,556.15      147.52
# 240.00                   5,907.75               0.00      118.33
# 300.00                   8,184.92           2,280.38      185.15
# 360.00                   5,298.08           1,562.26      147.25
# 480.00                   4,398.93           1,013.00      151.80

# %%
sns.set_style("white")
sns.barplot(x='Education',y='LoanAmount', hue='Loan_Status',data=loan)

# %%
sns.countplot(x='Married', hue='Loan_Status', data=loan); ##same as barplot but it has no Y axis###

# %%
fig, ax = plt.subplots()
ax.set(title = "Scatter ploat of Applicant Income vs Loan Amount", xlabel="Applicant Income", ylabel="Loan Amount")
plt.scatter(x='ApplicantIncome',y='LoanAmount',data=loan)
plt.show()

# %%
sns.regplot(x=loan["ApplicantIncome"], y=loan["LoanAmount"], fit_reg=True)

# %%
sns.jointplot("ApplicantIncome", "LoanAmount", loan, kind="reg")

# %%
loan_num = loan[["ApplicantIncome","CoapplicantIncome","LoanAmount","Loan_Amount_Term"]]
correlations = loan_num.corr()

fig, ax=plt.subplots()
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ax.set(xticklabels=loan_num.columns,yticklabels=loan_num.columns)
plt.show()

# %%
#seaborn
sns.heatmap(correlations)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#Drop missing observations
loan_no_missing = loan.dropna()
loan_no_missing
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#Drop rows where all cells in that row is NA
loan_cleaned = loan.dropna(how='all')
loan_cleaned
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#Drop rows where all cells in that row is NA
loan_cleaned2 = loan.dropna(how='any',axis=1)
loan_cleaned2
# Out:
#       Loan_ID     Education  ApplicantIncome  CoapplicantIncome Property_Area  \
# 0    LP001002      Graduate             5849               0.00         Urban
# 1    LP001003      Graduate             4583           1,508.00         Rural
# 2    LP001005      Graduate             3000               0.00         Urban
# 3    LP001006  Not Graduate             2583           2,358.00         Urban
# 4    LP001008      Graduate             6000               0.00         Urban
# ..        ...           ...              ...                ...           ...
# 609  LP002978      Graduate             2900               0.00         Rural
# 610  LP002979      Graduate             4106               0.00         Rural
# 611  LP002983      Graduate             8072             240.00         Urban
# 612  LP002984      Graduate             7583               0.00         Urban
# 613  LP002990      Graduate             4583               0.00     Semiurban
#
#     Loan_Status
# ...

# %%
#We can fill NA entries with a single value, such as zero:
loan_fil = loan.fillna(0)
loan_fil
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#Fill in missing in preTestScore with the mean value of preTestScore
#inplace=True means that the changes are saved to the df right away
loan2 =loan

loan2["LoanAmount"].fillna(loan2["LoanAmount"].mean(), inplace=True)
loan2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
